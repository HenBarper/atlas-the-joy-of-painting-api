# %%
import pandas as pd

# %%
df = pd.read_csv('data/colors_used.csv')

# %%
df
# Out:
#                                                img_src  \
# 0    https://www.twoinchbrush.com/images/painting28...
# 1    https://www.twoinchbrush.com/images/painting28...
# 2    https://www.twoinchbrush.com/images/painting28...
# 3    https://www.twoinchbrush.com/images/painting28...
# 4    https://www.twoinchbrush.com/images/painting28...
# 5    https://www.twoinchbrush.com/images/painting28...
# 6    https://www.twoinchbrush.com/images/painting28...
# 7    https://www.twoinchbrush.com/images/painting28...
# 8    https://www.twoinchbrush.com/images/painting29...
# 9    https://www.twoinchbrush.com/images/painting29...
# 10   https://www.twoinchbrush.com/images/painting29...
# 11   https://www.twoinchbrush.com/images/painting29...
# 12   https://www.twoinchbrush.com/images/painting29...
# 13   https://www.twoinchbrush.com/images/painting26...
# 14   https://www.twoinchbrush.com/images/painting27...
# 15   https://www.twoinchbrush.com/images/painting27...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   img_src           403 non-null    object
#  1   painting_title    403 non-null    object
#  2   season            403 non-null    int64
#  3   episode           403 non-null    int64
#  4   youtube_src       403 non-null    object
#  5   colors            403 non-null    object
#  6   color_hex         403 non-null    object
#  7   Black_Gesso       403 non-null    int64
#  8   Bright_Red        403 non-null    int64
#  9   Burnt_Umber       403 non-null    int64
#  10  Cadmium_Yellow    403 non-null    int64
#  11  Dark_Sienna       403 non-null    int64
#  12  Indian_Red        403 non-null    int64
#  13  Indian_Yellow     403 non-null    int64
#  14  Liquid_Black      403 non-null    int64
#  15  Liquid_Clear      403 non-null    int64
# ...

# %%
df.loc[0]
# Out:
# img_src             https://www.twoinchbrush.com/images/painting28...
# painting_title                                    A Walk in the Woods
# season                                                              1
# episode                                                             1
# youtube_src                 https://www.youtube.com/embed/oh5p5f5_-7A
# colors              ['Alizarin Crimson', 'Bright Red', 'Cadmium Ye...
# color_hex           ['#4E1500', '#DB0000', '#FFEC00', '#102E3C', '...
# Black_Gesso                                                         0
# Bright_Red                                                          1
# Burnt_Umber                                                         0
# Cadmium_Yellow                                                      1
# Dark_Sienna                                                         0
# Indian_Red                                                          0
# ...
