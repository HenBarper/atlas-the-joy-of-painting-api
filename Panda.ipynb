# %%
import pandas as pd

# %%
df = pd.read_csv('data/colors_used.csv')

# %%
df
# Out:
#      Unnamed: 0  painting_index  \
# 0             1             282
# 1             2             283
# 2             3             284
# 3             4             285
# 4             5             286
# ..          ...             ...
# 398         399             407
# 399         400             408
# 400         401             409
# 401         402             410
# 402         403             411
#
#                                                img_src  \
# 0    https://www.twoinchbrush.com/images/painting28...
# 1    https://www.twoinchbrush.com/images/painting28...
# 2    https://www.twoinchbrush.com/images/painting28...
# 3    https://www.twoinchbrush.com/images/painting28...
# 4    https://www.twoinchbrush.com/images/painting28...
# ..                                                 ...
# 398  https://www.twoinchbrush.com/images/painting40...
# 399  https://www.twoinchbrush.com/images/painting40...
# 400  https://www.twoinchbrush.com/images/painting40...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        403 non-null    int64
#  1   painting_index    403 non-null    int64
#  2   img_src           403 non-null    object
#  3   painting_title    403 non-null    object
#  4   season            403 non-null    int64
#  5   episode           403 non-null    int64
#  6   num_colors        403 non-null    int64
#  7   youtube_src       403 non-null    object
#  8   colors            403 non-null    object
#  9   color_hex         403 non-null    object
#  10  Black_Gesso       403 non-null    int64
#  11  Bright_Red        403 non-null    int64
#  12  Burnt_Umber       403 non-null    int64
#  13  Cadmium_Yellow    403 non-null    int64
#  14  Dark_Sienna       403 non-null    int64
#  15  Indian_Red        403 non-null    int64
# ...

# %%
df.loc[0]
# Out:
# Unnamed: 0                                                          1
# painting_index                                                    282
# img_src             https://www.twoinchbrush.com/images/painting28...
# painting_title                                    A Walk in the Woods
# season                                                              1
# episode                                                             1
# num_colors                                                          8
# youtube_src                 https://www.youtube.com/embed/oh5p5f5_-7A
# colors              ['Alizarin Crimson', 'Bright Red', 'Cadmium Ye...
# color_hex           ['#4E1500', '#DB0000', '#FFEC00', '#102E3C', '...
# Black_Gesso                                                         0
# Bright_Red                                                          1
# Burnt_Umber                                                         0
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\benja\AppData\Local\Programs\Python\Python311\python.exe
