# %%
import pandas as pd

# %%
df = pd.read_csv('data/subject_matter.csv')

# %%
df
# Out:
#     EPISODE                     TITLE  APPLE_FRAME  AURORA_BOREALIS  BARN  \
# 0    S01E01     "A WALK IN THE WOODS"            0                0     0
# 1    S01E02            "MT. MCKINLEY"            0                0     0
# 2    S01E03            "EBONY SUNSET"            0                0     0
# 3    S01E04             "WINTER MIST"            0                0     0
# 4    S01E05            "QUIET STREAM"            0                0     0
# ..      ...                       ...          ...              ...   ...
# 398  S31E09        "EVERGREEN VALLEY"            0                0     0
# 399  S31E10             "BALMY BEACH"            0                0     0
# 400  S31E11       "LAKE AT THE RIDGE"            0                0     0
# 401  S31E12  "IN THE MIDST OF WINTER"            0                0     1
# 402  S31E13          "WILDERNESS DAY"            0                0     0
#
#      ...  WAVES  WINDMILL  WINDOW_FRAME  WINTER  WOOD_FRAMED
# ...

# %%
df.shape
# Out:
# (403, 69)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 69 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EPISODE             403 non-null    object
#  1   TITLE               403 non-null    object
#  2   APPLE_FRAME         403 non-null    int64
#  3   AURORA_BOREALIS     403 non-null    int64
#  4   BARN                403 non-null    int64
#  5   BEACH               403 non-null    int64
#  6   BOAT                403 non-null    int64
#  7   BRIDGE              403 non-null    int64
#  8   BUILDING            403 non-null    int64
#  9   BUSHES              403 non-null    int64
#  10  CABIN               403 non-null    int64
#  11  CACTUS              403 non-null    int64
#  12  CIRCLE_FRAME        403 non-null    int64
#  13  CIRRUS              403 non-null    int64
#  14  CLIFF               403 non-null    int64
#  15  CLOUDS              403 non-null    int64
# ...

# %%
pd.set_option('display.max_columns', 10)
